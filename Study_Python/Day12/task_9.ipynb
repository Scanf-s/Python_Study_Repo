# %% [markdown]
# animals라는 패키지를 만들고, 이 패키지 내에 mammals, birds라는 두 개의 서브 모듈을 생성하세요.
#
# - 각 모듈에는 최소한 한 개 이상의 동물에 관한 클래스를 정의하세요<br>
#   (예: mammals에는 Dog, birds에는 Eagle)
# - 이 패키지와 모듈을 사용하여 동물들의 정보를 출력하는 프로그램을 작성
#
# 폴더 및 파일 구조
# ```
# animals/(폴더)
# ├── __init__.py
# ├── mammals.py
# └── birds.py
# ```

# %%
from animals.mammals import Dog
from animals.birds import Eagle

# Dog 인스턴스 생성
my_dog = Dog("복순이")
print(f"{my_dog.name}가 짖습니다 : {my_dog.speak()}")

# Eagle 인스턴스 생성
my_eagle = Eagle("대머리 독수리")
print(f"{my_eagle.name}가 날면서 웁니다 : {my_eagle.speak()}")
# Out:
# 복순이가 짖습니다 : 왈왈왈 크르르.... 왈왈왈왈
# 대머리 독수리가 날면서 웁니다 : 끼에에에에에엑
